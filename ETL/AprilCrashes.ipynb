# %%
import pandas as pd
import csv
from sqlalchemy import create_engine

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import numpy as np
import datetime

# %%
file_one = "Data/April_Motorvehicles.csv"

# %%
crashes2020 = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
crashes2020.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  04/01/2020      21:23  BROOKLYN   11219.0  40.634270 -73.983310
# 1  04/01/2020      16:09       NaN       NaN  40.665660 -73.767624
# 2  04/01/2020      21:18  BROOKLYN   11249.0  40.713078 -73.964080
# 3  04/01/2020      14:29       NaN       NaN  40.627926 -73.931750
# 4  04/01/2020      17:00    QUEENS   11378.0  40.725930 -73.918370
#
#                  LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0   (40.63427, -73.98331)                               NaN               NaN
# 1  (40.66566, -73.767624)  FARMERS BOULEVARD                         145 ROAD
# 2  (40.713078, -73.96408)  BERRY STREET                        SOUTH 3 STREET
# 3  (40.627926, -73.93175)  AVENUE J                                       NaN
# 4   (40.72593, -73.91837)  56 ROAD                                  50 STREET
#
#                             OFF STREET NAME  ...  \
# 0  1575      44 STREET                       ...
# 1                                       NaN  ...
# 2                                       NaN  ...
# 3                                       NaN  ...
# 4                                       NaN  ...
#
#    CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                    Unspecified                            NaN
# 1                    Unspecified                            NaN
# 2  Failure to Yield Right-of-Way                            NaN
# 3                    Unspecified                            NaN
# 4                    Unspecified                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN       4308629
# 1                            NaN                            NaN       4305069
# 2                            NaN                            NaN       4307292
# 3                            NaN                            NaN       4305138
# 4                            NaN                            NaN       4305053
#
#                    VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 0  Station Wagon/Sport Utility Vehicle                                  Van
# 1  Station Wagon/Sport Utility Vehicle  Station Wagon/Sport Utility Vehicle
# 2  Station Wagon/Sport Utility Vehicle                               E-Bike
# 3                                Sedan  Station Wagon/Sport Utility Vehicle
# 4                                Sedan                            Box Truck
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
# del crashes2020['ON STREET NAME']
# del crashes2020['CROSS STREET NAME']
# del crashes2020['OFF STREET NAME']
# del crashes2020['CONTRIBUTING FACTOR VEHICLE 3']
# del crashes2020['CONTRIBUTING FACTOR VEHICLE 4']
# del crashes2020['CONTRIBUTING FACTOR VEHICLE 5']
# del crashes2020['VEHICLE TYPE CODE 3']
# del crashes2020['VEHICLE TYPE CODE 4']
# del crashes2020['VEHICLE TYPE CODE 5']

# %%
crashes2020



crashes2020 = crashes2020[crashes2020['BOROUGH'].notna()]

# %%
crashes2020 = crashes2020[crashes2020['LATITUDE'].notna()]

# %%
crashes2020 = crashes2020[crashes2020['LONGITUDE'].notna()]

# %%
crashes2020
# Out:
#       CRASH DATE CRASH TIME        BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     04/01/2020      21:23       BROOKLYN   11219.0  40.634270 -73.983310
# 2     04/01/2020      21:18       BROOKLYN   11249.0  40.713078 -73.964080
# 4     04/01/2020      17:00         QUEENS   11378.0  40.725930 -73.918370
# 6     04/01/2020      12:50  STATEN ISLAND   10305.0  40.583390 -74.089790
# 7     04/01/2020       7:00      MANHATTAN   10035.0  40.807310 -73.939514
# ...          ...        ...            ...       ...        ...        ...
# 4113  04/30/2020      22:25          BRONX   10465.0  40.828075 -73.840065
# 4114  04/30/2020       8:00       BROOKLYN   11213.0  40.671703 -73.935240
# 4115  04/30/2020      11:51         QUEENS   11369.0  40.767740 -73.879990
# 4119  04/30/2020      16:00       BROOKLYN   11233.0  40.669600 -73.919690
# 4120  04/30/2020      12:50          BRONX   10451.0  40.823063 -73.910010
#
#                      LOCATION                    ON STREET NAME  \
# 0       (40.63427, -73.98331)                               NaN
# 2      (40.713078, -73.96408)  BERRY STREET
# 4       (40.72593, -73.91837)  56 ROAD
# 6       (40.58339, -74.08979)  BUEL AVENUE
# 7      (40.80731, -73.939514)                               NaN
# ...                       ...                               ...
# 4113  (40.828075, -73.840065)                               NaN
# 4114   (40.671703, -73.93524)                               NaN
# 4115    (40.76774, -73.87999)  90 STREET
# 4119     (40.6696, -73.91969)                               NaN
# 4120   (40.823063, -73.91001)                               NaN
#
#      CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0                  NaN  1575      44 STREET                       ...
# 2       SOUTH 3 STREET                                       NaN  ...
# 4            50 STREET                                       NaN  ...
# 6         MASON AVENUE                                       NaN  ...
# 7                  NaN  2004      MADISON AVENUE                  ...
# ...                ...                                       ...  ...
# 4113               NaN  2560      BRUCKNER BOULEVARD              ...
# 4114               NaN  1308      STERLING PLACE                  ...
# 4115         23 AVENUE                                       NaN  ...
# 4119               NaN  1463      EASTERN PARKWAY                 ...
# 4120               NaN  507       EAST 161 STREET                 ...
#
#       CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                       Unspecified                            NaN
# 2     Failure to Yield Right-of-Way                            NaN
# 4                       Unspecified                            NaN
# 6                       Unspecified                            NaN
# 7                               NaN                            NaN
# ...                             ...                            ...
# 4113                            NaN                            NaN
# 4114                    Unspecified                            NaN
# 4115                    Unspecified                    Unspecified
# 4119                    Unspecified                            NaN
# 4120                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 0                               NaN                            NaN
# 2                               NaN                            NaN
# 4                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# ...                             ...                            ...
# 4113                            NaN                            NaN
# 4114                            NaN                            NaN
# 4115                            NaN                            NaN
# 4119                            NaN                            NaN
# 4120                            NaN                            NaN
#
#       COLLISION_ID                  VEHICLE TYPE CODE 1  \
# 0          4308629  Station Wagon/Sport Utility Vehicle
# 2          4307292  Station Wagon/Sport Utility Vehicle
# 4          4305053                                Sedan
# 6          4305083                                Sedan
# 7          4307401                                Sedan
# ...            ...                                  ...
# 4113       4311274  Station Wagon/Sport Utility Vehicle
# 4114       4312115                                Sedan
# 4115       4311205                                Sedan
# 4119       4311361  Station Wagon/Sport Utility Vehicle
# 4120       4311379                                Sedan
#
#                       VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 0                                     Van                  NaN
# 2                                  E-Bike                  NaN
# 4                               Box Truck                  NaN
# 6                                   Sedan                  NaN
# 7                                     NaN                  NaN
# ...                                   ...                  ...
# 4113                                  NaN                  NaN
# 4114  Station Wagon/Sport Utility Vehicle                  NaN
# 4115                                Sedan                Sedan
# 4119  Station Wagon/Sport Utility Vehicle                  NaN
# 4120                                  NaN                  NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                    NaN                 NaN
# 2                    NaN                 NaN
# 4                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# ...                  ...                 ...
# 4113                 NaN                 NaN
# 4114                 NaN                 NaN
# 4115                 NaN                 NaN
# 4119                 NaN                 NaN
# 4120                 NaN                 NaN
#
# [2518 rows x 29 columns]

# %%
del crashes2020['CONTRIBUTING FACTOR VEHICLE 2']
del crashes2020['VEHICLE TYPE CODE 2']

# %%
crashes2020_df = crashes2020.rename(columns={"CRASH DATE":"CrashDate", "CRASH TIME": "CrashTime", "ZIP CODE": "ZipCode",
                                            "NUMBER OF PERSONS INJURED": "PersonsInjured", "NUMBER OF PERSONS KILLED": "PersonsKilled",
                                            "NUMBER OF PEDESTRIANS INJURED": "PedestriansInjured", "NUMBER OF PEDESTRIANS KILLED": "PedestriansKilled", 
                                            "NUMBER OF CYCLIST INJURED": "CyclistInjured", "NUMBER OF CYCLIST KILLED": "CyclistKilled",
                                            "NUMBER OF MOTORIST INJURED": "MotoristInjured", "NUMBER OF MOTORIST KILLED": "MotoristKilled",
                                            "CONTRIBUTING FACTOR VEHICLE 1": "ContributingFactor", "VEHICLE TYPE CODE 1": "VehicleType"})

# %%
crashes2020_df
# Out:
#        CrashDate CrashTime        BOROUGH  ZipCode   LATITUDE  LONGITUDE  \
# 0     04/01/2020     21:23       BROOKLYN  11219.0  40.634270 -73.983310
# 2     04/01/2020     21:18       BROOKLYN  11249.0  40.713078 -73.964080
# 4     04/01/2020     17:00         QUEENS  11378.0  40.725930 -73.918370
# 6     04/01/2020     12:50  STATEN ISLAND  10305.0  40.583390 -74.089790
# 7     04/01/2020      7:00      MANHATTAN  10035.0  40.807310 -73.939514
# ...          ...       ...            ...      ...        ...        ...
# 4113  04/30/2020     22:25          BRONX  10465.0  40.828075 -73.840065
# 4114  04/30/2020      8:00       BROOKLYN  11213.0  40.671703 -73.935240
# 4115  04/30/2020     11:51         QUEENS  11369.0  40.767740 -73.879990
# 4119  04/30/2020     16:00       BROOKLYN  11233.0  40.669600 -73.919690
# 4120  04/30/2020     12:50          BRONX  10451.0  40.823063 -73.910010
#
#                      LOCATION                    ON STREET NAME  \
# 0       (40.63427, -73.98331)                               NaN
# 2      (40.713078, -73.96408)  BERRY STREET
# 4       (40.72593, -73.91837)  56 ROAD
# 6       (40.58339, -74.08979)  BUEL AVENUE
# 7      (40.80731, -73.939514)                               NaN
# ...                       ...                               ...
# 4113  (40.828075, -73.840065)                               NaN
# 4114   (40.671703, -73.93524)                               NaN
# 4115    (40.76774, -73.87999)  90 STREET
# 4119     (40.6696, -73.91969)                               NaN
# 4120   (40.823063, -73.91001)                               NaN
#
#      CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0                  NaN  1575      44 STREET                       ...
# 2       SOUTH 3 STREET                                       NaN  ...
# 4            50 STREET                                       NaN  ...
# 6         MASON AVENUE                                       NaN  ...
# 7                  NaN  2004      MADISON AVENUE                  ...
# ...                ...                                       ...  ...
# 4113               NaN  2560      BRUCKNER BOULEVARD              ...
# 4114               NaN  1308      STERLING PLACE                  ...
# 4115         23 AVENUE                                       NaN  ...
# 4119               NaN  1463      EASTERN PARKWAY                 ...
# 4120               NaN  507       EAST 161 STREET                 ...
#
#       MotoristKilled              ContributingFactor  \
# 0                  0                     Unspecified
# 2                  0   Failure to Yield Right-of-Way
# 4                  0  Driver Inattention/Distraction
# 6                  0  Driver Inattention/Distraction
# 7                  0                     Unspecified
# ...              ...                             ...
# 4113               0                     Unspecified
# 4114               0  Driver Inattention/Distraction
# 4115               0                     Unspecified
# 4119               0  Driver Inattention/Distraction
# 4120               0  Driver Inattention/Distraction
#
#       CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                               NaN                            NaN
# 2                               NaN                            NaN
# 4                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# ...                             ...                            ...
# 4113                            NaN                            NaN
# 4114                            NaN                            NaN
# 4115                    Unspecified                            NaN
# 4119                            NaN                            NaN
# 4120                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                               NaN       4308629
# 2                               NaN       4307292
# 4                               NaN       4305053
# 6                               NaN       4305083
# 7                               NaN       4307401
# ...                             ...           ...
# 4113                            NaN       4311274
# 4114                            NaN       4312115
# 4115                            NaN       4311205
# 4119                            NaN       4311361
# 4120                            NaN       4311379
#
#                               VehicleType  VEHICLE TYPE CODE 3  \
# 0     Station Wagon/Sport Utility Vehicle                  NaN
# 2     Station Wagon/Sport Utility Vehicle                  NaN
# 4                                   Sedan                  NaN
# 6                                   Sedan                  NaN
# 7                                   Sedan                  NaN
# ...                                   ...                  ...
# 4113  Station Wagon/Sport Utility Vehicle                  NaN
# 4114                                Sedan                  NaN
# 4115                                Sedan                Sedan
# 4119  Station Wagon/Sport Utility Vehicle                  NaN
# 4120                                Sedan                  NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                    NaN                 NaN
# 2                    NaN                 NaN
# 4                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# ...                  ...                 ...
# 4113                 NaN                 NaN
# 4114                 NaN                 NaN
# 4115                 NaN                 NaN
# 4119                 NaN                 NaN
# 4120                 NaN                 NaN
#
# [2518 rows x 27 columns]

# %%
crashes2020_df = crashes2020_df.rename(columns={"BOROUGH":"Borough", "LATITUDE": "Latitude", "LONGITUDE": "Longitude", 
                                                "LOCATION": "Location", "COLLISION_ID": "CollisionID"})

# %%
crashes2020_df
# Out:
#        CrashDate CrashTime        Borough  ZipCode   Latitude  Longitude  \
# 0     04/01/2020     21:23       BROOKLYN  11219.0  40.634270 -73.983310
# 2     04/01/2020     21:18       BROOKLYN  11249.0  40.713078 -73.964080
# 4     04/01/2020     17:00         QUEENS  11378.0  40.725930 -73.918370
# 6     04/01/2020     12:50  STATEN ISLAND  10305.0  40.583390 -74.089790
# 7     04/01/2020      7:00      MANHATTAN  10035.0  40.807310 -73.939514
# ...          ...       ...            ...      ...        ...        ...
# 4113  04/30/2020     22:25          BRONX  10465.0  40.828075 -73.840065
# 4114  04/30/2020      8:00       BROOKLYN  11213.0  40.671703 -73.935240
# 4115  04/30/2020     11:51         QUEENS  11369.0  40.767740 -73.879990
# 4119  04/30/2020     16:00       BROOKLYN  11233.0  40.669600 -73.919690
# 4120  04/30/2020     12:50          BRONX  10451.0  40.823063 -73.910010
#
#                      Location                    ON STREET NAME  \
# 0       (40.63427, -73.98331)                               NaN
# 2      (40.713078, -73.96408)  BERRY STREET
# 4       (40.72593, -73.91837)  56 ROAD
# 6       (40.58339, -74.08979)  BUEL AVENUE
# 7      (40.80731, -73.939514)                               NaN
# ...                       ...                               ...
# 4113  (40.828075, -73.840065)                               NaN
# 4114   (40.671703, -73.93524)                               NaN
# 4115    (40.76774, -73.87999)  90 STREET
# 4119     (40.6696, -73.91969)                               NaN
# 4120   (40.823063, -73.91001)                               NaN
#
#      CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0                  NaN  1575      44 STREET                       ...
# 2       SOUTH 3 STREET                                       NaN  ...
# 4            50 STREET                                       NaN  ...
# 6         MASON AVENUE                                       NaN  ...
# 7                  NaN  2004      MADISON AVENUE                  ...
# ...                ...                                       ...  ...
# 4113               NaN  2560      BRUCKNER BOULEVARD              ...
# 4114               NaN  1308      STERLING PLACE                  ...
# 4115         23 AVENUE                                       NaN  ...
# 4119               NaN  1463      EASTERN PARKWAY                 ...
# 4120               NaN  507       EAST 161 STREET                 ...
#
#       MotoristKilled              ContributingFactor  \
# 0                  0                     Unspecified
# 2                  0   Failure to Yield Right-of-Way
# 4                  0  Driver Inattention/Distraction
# 6                  0  Driver Inattention/Distraction
# 7                  0                     Unspecified
# ...              ...                             ...
# 4113               0                     Unspecified
# 4114               0  Driver Inattention/Distraction
# 4115               0                     Unspecified
# 4119               0  Driver Inattention/Distraction
# 4120               0  Driver Inattention/Distraction
#
#       CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                               NaN                            NaN
# 2                               NaN                            NaN
# 4                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# ...                             ...                            ...
# 4113                            NaN                            NaN
# 4114                            NaN                            NaN
# 4115                    Unspecified                            NaN
# 4119                            NaN                            NaN
# 4120                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 5  CollisionID  \
# 0                               NaN      4308629
# 2                               NaN      4307292
# 4                               NaN      4305053
# 6                               NaN      4305083
# 7                               NaN      4307401
# ...                             ...          ...
# 4113                            NaN      4311274
# 4114                            NaN      4312115
# 4115                            NaN      4311205
# 4119                            NaN      4311361
# 4120                            NaN      4311379
#
#                               VehicleType  VEHICLE TYPE CODE 3  \
# 0     Station Wagon/Sport Utility Vehicle                  NaN
# 2     Station Wagon/Sport Utility Vehicle                  NaN
# 4                                   Sedan                  NaN
# 6                                   Sedan                  NaN
# 7                                   Sedan                  NaN
# ...                                   ...                  ...
# 4113  Station Wagon/Sport Utility Vehicle                  NaN
# 4114                                Sedan                  NaN
# 4115                                Sedan                Sedan
# 4119  Station Wagon/Sport Utility Vehicle                  NaN
# 4120                                Sedan                  NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                    NaN                 NaN
# 2                    NaN                 NaN
# 4                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# ...                  ...                 ...
# 4113                 NaN                 NaN
# 4114                 NaN                 NaN
# 4115                 NaN                 NaN
# 4119                 NaN                 NaN
# 4120                 NaN                 NaN
#
# [2518 rows x 27 columns]

# %%
del crashes2020_df['Location']

# %%
crashes2020_df["CrashDate"] = pd.to_datetime(crashes2020_df["CrashDate"]).dt.strftime('%Y-%m-%d')
print(crashes2020_df)
# Out:
#        CrashDate CrashTime        Borough  ZipCode   Latitude  Longitude  \
# 0     2020-04-01     21:23       BROOKLYN  11219.0  40.634270 -73.983310
# 2     2020-04-01     21:18       BROOKLYN  11249.0  40.713078 -73.964080
# 4     2020-04-01     17:00         QUEENS  11378.0  40.725930 -73.918370
# 6     2020-04-01     12:50  STATEN ISLAND  10305.0  40.583390 -74.089790
# 7     2020-04-01      7:00      MANHATTAN  10035.0  40.807310 -73.939514
# ...          ...       ...            ...      ...        ...        ...
# 4113  2020-04-30     22:25          BRONX  10465.0  40.828075 -73.840065
# 4114  2020-04-30      8:00       BROOKLYN  11213.0  40.671703 -73.935240
# 4115  2020-04-30     11:51         QUEENS  11369.0  40.767740 -73.879990
# 4119  2020-04-30     16:00       BROOKLYN  11233.0  40.669600 -73.919690
# 4120  2020-04-30     12:50          BRONX  10451.0  40.823063 -73.910010
#
#                         ON STREET NAME CROSS STREET NAME  \
# 0                                  NaN               NaN
# 2     BERRY STREET                        SOUTH 3 STREET
# 4     56 ROAD                                  50 STREET
# 6     BUEL AVENUE                           MASON AVENUE
# 7                                  NaN               NaN
# ...                                ...               ...
# 4113                               NaN               NaN
# 4114                               NaN               NaN
# 4115  90 STREET                                23 AVENUE
# 4119                               NaN               NaN
# 4120                               NaN               NaN
#
#                                OFF STREET NAME  PersonsInjured  ...  \
# 0     1575      44 STREET                                    0  ...
# 2                                          NaN               1  ...
# 4                                          NaN               0  ...
# 6                                          NaN               1  ...
# 7     2004      MADISON AVENUE                               0  ...
# ...                                        ...             ...  ...
# 4113  2560      BRUCKNER BOULEVARD                           1  ...
# 4114  1308      STERLING PLACE                               0  ...
# 4115                                       NaN               0  ...
# 4119  1463      EASTERN PARKWAY                              0  ...
# 4120  507       EAST 161 STREET                              0  ...
#
#       MotoristKilled              ContributingFactor  \
# 0                  0                     Unspecified
# 2                  0   Failure to Yield Right-of-Way
# 4                  0  Driver Inattention/Distraction
# 6                  0  Driver Inattention/Distraction
# 7                  0                     Unspecified
# ...              ...                             ...
# 4113               0                     Unspecified
# 4114               0  Driver Inattention/Distraction
# 4115               0                     Unspecified
# 4119               0  Driver Inattention/Distraction
# 4120               0  Driver Inattention/Distraction
#
#       CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                               NaN                            NaN
# 2                               NaN                            NaN
# 4                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# ...                             ...                            ...
# 4113                            NaN                            NaN
# 4114                            NaN                            NaN
# 4115                    Unspecified                            NaN
# 4119                            NaN                            NaN
# 4120                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 5  CollisionID  \
# 0                               NaN      4308629
# 2                               NaN      4307292
# 4                               NaN      4305053
# 6                               NaN      4305083
# 7                               NaN      4307401
# ...                             ...          ...
# 4113                            NaN      4311274
# 4114                            NaN      4312115
# 4115                            NaN      4311205
# 4119                            NaN      4311361
# 4120                            NaN      4311379
#
#                               VehicleType VEHICLE TYPE CODE 3  \
# 0     Station Wagon/Sport Utility Vehicle                 NaN
# 2     Station Wagon/Sport Utility Vehicle                 NaN
# 4                                   Sedan                 NaN
# 6                                   Sedan                 NaN
# 7                                   Sedan                 NaN
# ...                                   ...                 ...
# 4113  Station Wagon/Sport Utility Vehicle                 NaN
# 4114                                Sedan                 NaN
# 4115                                Sedan               Sedan
# 4119  Station Wagon/Sport Utility Vehicle                 NaN
# 4120                                Sedan                 NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                    NaN                 NaN
# 2                    NaN                 NaN
# 4                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# ...                  ...                 ...
# 4113                 NaN                 NaN
# 4114                 NaN                 NaN
# 4115                 NaN                 NaN
# 4119                 NaN                 NaN
# 4120                 NaN                 NaN
#
# [2518 rows x 26 columns]

# %%
clean_crashes=crashes2020_df

# %%
del crashes2020_df['ZipCode']

# %%
crashes2020_df
# Out:
#        CrashDate CrashTime        Borough   Latitude  Longitude  \
# 0     2020-04-01     21:23       BROOKLYN  40.634270 -73.983310
# 2     2020-04-01     21:18       BROOKLYN  40.713078 -73.964080
# 4     2020-04-01     17:00         QUEENS  40.725930 -73.918370
# 6     2020-04-01     12:50  STATEN ISLAND  40.583390 -74.089790
# 7     2020-04-01      7:00      MANHATTAN  40.807310 -73.939514
# ...          ...       ...            ...        ...        ...
# 4113  2020-04-30     22:25          BRONX  40.828075 -73.840065
# 4114  2020-04-30      8:00       BROOKLYN  40.671703 -73.935240
# 4115  2020-04-30     11:51         QUEENS  40.767740 -73.879990
# 4119  2020-04-30     16:00       BROOKLYN  40.669600 -73.919690
# 4120  2020-04-30     12:50          BRONX  40.823063 -73.910010
#
#                         ON STREET NAME CROSS STREET NAME  \
# 0                                  NaN               NaN
# 2     BERRY STREET                        SOUTH 3 STREET
# 4     56 ROAD                                  50 STREET
# 6     BUEL AVENUE                           MASON AVENUE
# 7                                  NaN               NaN
# ...                                ...               ...
# 4113                               NaN               NaN
# 4114                               NaN               NaN
# 4115  90 STREET                                23 AVENUE
# 4119                               NaN               NaN
# 4120                               NaN               NaN
#
#                                OFF STREET NAME  PersonsInjured  PersonsKilled  \
# 0     1575      44 STREET                                    0              0
# 2                                          NaN               1              0
# 4                                          NaN               0              0
# 6                                          NaN               1              0
# 7     2004      MADISON AVENUE                               0              0
# ...                                        ...             ...            ...
# 4113  2560      BRUCKNER BOULEVARD                           1              0
# 4114  1308      STERLING PLACE                               0              0
# 4115                                       NaN               0              0
# 4119  1463      EASTERN PARKWAY                              0              0
# 4120  507       EAST 161 STREET                              0              0
#
#       ...  MotoristKilled              ContributingFactor  \
# 0     ...               0                     Unspecified
# 2     ...               0   Failure to Yield Right-of-Way
# 4     ...               0  Driver Inattention/Distraction
# 6     ...               0  Driver Inattention/Distraction
# 7     ...               0                     Unspecified
# ...   ...             ...                             ...
# 4113  ...               0                     Unspecified
# 4114  ...               0  Driver Inattention/Distraction
# 4115  ...               0                     Unspecified
# 4119  ...               0  Driver Inattention/Distraction
# 4120  ...               0  Driver Inattention/Distraction
#
#       CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                               NaN                            NaN
# 2                               NaN                            NaN
# 4                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# ...                             ...                            ...
# 4113                            NaN                            NaN
# 4114                            NaN                            NaN
# 4115                    Unspecified                            NaN
# 4119                            NaN                            NaN
# 4120                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 5  CollisionID  \
# 0                               NaN      4308629
# 2                               NaN      4307292
# 4                               NaN      4305053
# 6                               NaN      4305083
# 7                               NaN      4307401
# ...                             ...          ...
# 4113                            NaN      4311274
# 4114                            NaN      4312115
# 4115                            NaN      4311205
# 4119                            NaN      4311361
# 4120                            NaN      4311379
#
#                               VehicleType VEHICLE TYPE CODE 3  \
# 0     Station Wagon/Sport Utility Vehicle                 NaN
# 2     Station Wagon/Sport Utility Vehicle                 NaN
# 4                                   Sedan                 NaN
# 6                                   Sedan                 NaN
# 7                                   Sedan                 NaN
# ...                                   ...                 ...
# 4113  Station Wagon/Sport Utility Vehicle                 NaN
# 4114                                Sedan                 NaN
# 4115                                Sedan               Sedan
# 4119  Station Wagon/Sport Utility Vehicle                 NaN
# 4120                                Sedan                 NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                    NaN                 NaN
# 2                    NaN                 NaN
# 4                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# ...                  ...                 ...
# 4113                 NaN                 NaN
# 4114                 NaN                 NaN
# 4115                 NaN                 NaN
# 4119                 NaN                 NaN
# 4120                 NaN                 NaN
#
# [2518 rows x 25 columns]

# %%
crashes2020_df=crashes2020_df.round({'Latitude': 4, 'Longitude': 4})

# %%
crashes2020_df
# Out:
#        CrashDate CrashTime        Borough  Latitude  Longitude  \
# 0     2020-04-01     21:23       BROOKLYN   40.6343   -73.9833
# 2     2020-04-01     21:18       BROOKLYN   40.7131   -73.9641
# 4     2020-04-01     17:00         QUEENS   40.7259   -73.9184
# 6     2020-04-01     12:50  STATEN ISLAND   40.5834   -74.0898
# 7     2020-04-01      7:00      MANHATTAN   40.8073   -73.9395
# ...          ...       ...            ...       ...        ...
# 4113  2020-04-30     22:25          BRONX   40.8281   -73.8401
# 4114  2020-04-30      8:00       BROOKLYN   40.6717   -73.9352
# 4115  2020-04-30     11:51         QUEENS   40.7677   -73.8800
# 4119  2020-04-30     16:00       BROOKLYN   40.6696   -73.9197
# 4120  2020-04-30     12:50          BRONX   40.8231   -73.9100
#
#                         ON STREET NAME CROSS STREET NAME  \
# 0                                  NaN               NaN
# 2     BERRY STREET                        SOUTH 3 STREET
# 4     56 ROAD                                  50 STREET
# 6     BUEL AVENUE                           MASON AVENUE
# 7                                  NaN               NaN
# ...                                ...               ...
# 4113                               NaN               NaN
# 4114                               NaN               NaN
# 4115  90 STREET                                23 AVENUE
# 4119                               NaN               NaN
# 4120                               NaN               NaN
#
#                                OFF STREET NAME  PersonsInjured  PersonsKilled  \
# 0     1575      44 STREET                                    0              0
# 2                                          NaN               1              0
# 4                                          NaN               0              0
# 6                                          NaN               1              0
# 7     2004      MADISON AVENUE                               0              0
# ...                                        ...             ...            ...
# 4113  2560      BRUCKNER BOULEVARD                           1              0
# 4114  1308      STERLING PLACE                               0              0
# 4115                                       NaN               0              0
# 4119  1463      EASTERN PARKWAY                              0              0
# 4120  507       EAST 161 STREET                              0              0
#
#       ...  MotoristKilled              ContributingFactor  \
# 0     ...               0                     Unspecified
# 2     ...               0   Failure to Yield Right-of-Way
# 4     ...               0  Driver Inattention/Distraction
# 6     ...               0  Driver Inattention/Distraction
# 7     ...               0                     Unspecified
# ...   ...             ...                             ...
# 4113  ...               0                     Unspecified
# 4114  ...               0  Driver Inattention/Distraction
# 4115  ...               0                     Unspecified
# 4119  ...               0  Driver Inattention/Distraction
# 4120  ...               0  Driver Inattention/Distraction
#
#       CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                               NaN                            NaN
# 2                               NaN                            NaN
# 4                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# ...                             ...                            ...
# 4113                            NaN                            NaN
# 4114                            NaN                            NaN
# 4115                    Unspecified                            NaN
# 4119                            NaN                            NaN
# 4120                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 5  CollisionID  \
# 0                               NaN      4308629
# 2                               NaN      4307292
# 4                               NaN      4305053
# 6                               NaN      4305083
# 7                               NaN      4307401
# ...                             ...          ...
# 4113                            NaN      4311274
# 4114                            NaN      4312115
# 4115                            NaN      4311205
# 4119                            NaN      4311361
# 4120                            NaN      4311379
#
#                               VehicleType VEHICLE TYPE CODE 3  \
# 0     Station Wagon/Sport Utility Vehicle                 NaN
# 2     Station Wagon/Sport Utility Vehicle                 NaN
# 4                                   Sedan                 NaN
# 6                                   Sedan                 NaN
# 7                                   Sedan                 NaN
# ...                                   ...                 ...
# 4113  Station Wagon/Sport Utility Vehicle                 NaN
# 4114                                Sedan                 NaN
# 4115                                Sedan               Sedan
# 4119  Station Wagon/Sport Utility Vehicle                 NaN
# 4120                                Sedan                 NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                    NaN                 NaN
# 2                    NaN                 NaN
# 4                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# ...                  ...                 ...
# 4113                 NaN                 NaN
# 4114                 NaN                 NaN
# 4115                 NaN                 NaN
# 4119                 NaN                 NaN
# 4120                 NaN                 NaN
#
# [2518 rows x 25 columns]

# %% [markdown]
# # Borough Totals

# %%
crashes2020_df
# Out:
#        CrashDate CrashTime        Borough  Latitude  Longitude  \
# 0     2020-04-01     21:23       BROOKLYN   40.6343   -73.9833
# 2     2020-04-01     21:18       BROOKLYN   40.7131   -73.9641
# 4     2020-04-01     17:00         QUEENS   40.7259   -73.9184
# 6     2020-04-01     12:50  STATEN ISLAND   40.5834   -74.0898
# 7     2020-04-01      7:00      MANHATTAN   40.8073   -73.9395
# ...          ...       ...            ...       ...        ...
# 4113  2020-04-30     22:25          BRONX   40.8281   -73.8401
# 4114  2020-04-30      8:00       BROOKLYN   40.6717   -73.9352
# 4115  2020-04-30     11:51         QUEENS   40.7677   -73.8800
# 4119  2020-04-30     16:00       BROOKLYN   40.6696   -73.9197
# 4120  2020-04-30     12:50          BRONX   40.8231   -73.9100
#
#                         ON STREET NAME CROSS STREET NAME  \
# 0                                  NaN               NaN
# 2     BERRY STREET                        SOUTH 3 STREET
# 4     56 ROAD                                  50 STREET
# 6     BUEL AVENUE                           MASON AVENUE
# 7                                  NaN               NaN
# ...                                ...               ...
# 4113                               NaN               NaN
# 4114                               NaN               NaN
# 4115  90 STREET                                23 AVENUE
# 4119                               NaN               NaN
# 4120                               NaN               NaN
#
#                                OFF STREET NAME  PersonsInjured  PersonsKilled  \
# 0     1575      44 STREET                                    0              0
# 2                                          NaN               1              0
# 4                                          NaN               0              0
# 6                                          NaN               1              0
# 7     2004      MADISON AVENUE                               0              0
# ...                                        ...             ...            ...
# 4113  2560      BRUCKNER BOULEVARD                           1              0
# 4114  1308      STERLING PLACE                               0              0
# 4115                                       NaN               0              0
# 4119  1463      EASTERN PARKWAY                              0              0
# 4120  507       EAST 161 STREET                              0              0
#
#       ...  MotoristKilled              ContributingFactor  \
# 0     ...               0                     Unspecified
# 2     ...               0   Failure to Yield Right-of-Way
# 4     ...               0  Driver Inattention/Distraction
# 6     ...               0  Driver Inattention/Distraction
# 7     ...               0                     Unspecified
# ...   ...             ...                             ...
# 4113  ...               0                     Unspecified
# 4114  ...               0  Driver Inattention/Distraction
# 4115  ...               0                     Unspecified
# 4119  ...               0  Driver Inattention/Distraction
# 4120  ...               0  Driver Inattention/Distraction
#
#       CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                               NaN                            NaN
# 2                               NaN                            NaN
# 4                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# ...                             ...                            ...
# 4113                            NaN                            NaN
# 4114                            NaN                            NaN
# 4115                    Unspecified                            NaN
# 4119                            NaN                            NaN
# 4120                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 5  CollisionID  \
# 0                               NaN      4308629
# 2                               NaN      4307292
# 4                               NaN      4305053
# 6                               NaN      4305083
# 7                               NaN      4307401
# ...                             ...          ...
# 4113                            NaN      4311274
# 4114                            NaN      4312115
# 4115                            NaN      4311205
# 4119                            NaN      4311361
# 4120                            NaN      4311379
#
#                               VehicleType VEHICLE TYPE CODE 3  \
# 0     Station Wagon/Sport Utility Vehicle                 NaN
# 2     Station Wagon/Sport Utility Vehicle                 NaN
# 4                                   Sedan                 NaN
# 6                                   Sedan                 NaN
# 7                                   Sedan                 NaN
# ...                                   ...                 ...
# 4113  Station Wagon/Sport Utility Vehicle                 NaN
# 4114                                Sedan                 NaN
# 4115                                Sedan               Sedan
# 4119  Station Wagon/Sport Utility Vehicle                 NaN
# 4120                                Sedan                 NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                    NaN                 NaN
# 2                    NaN                 NaN
# 4                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# ...                  ...                 ...
# 4113                 NaN                 NaN
# 4114                 NaN                 NaN
# 4115                 NaN                 NaN
# 4119                 NaN                 NaN
# 4120                 NaN                 NaN
#
# [2518 rows x 25 columns]

# %%
del crashes2020_df["ON STREET NAME"]
del crashes2020_df["CROSS STREET NAME"]
del crashes2020_df["OFF STREET NAME"]

# %%
crashes2020_df.head()
# Out:
#     CrashDate CrashTime        Borough  Latitude  Longitude  PersonsInjured  \
# 0  2020-04-01     21:23       BROOKLYN   40.6343   -73.9833               0
# 2  2020-04-01     21:18       BROOKLYN   40.7131   -73.9641               1
# 4  2020-04-01     17:00         QUEENS   40.7259   -73.9184               0
# 6  2020-04-01     12:50  STATEN ISLAND   40.5834   -74.0898               1
# 7  2020-04-01      7:00      MANHATTAN   40.8073   -73.9395               0
#
#    PersonsKilled  PedestriansInjured  PedestriansKilled  CyclistInjured  ...  \
# 0              0                   0                  0               0  ...
# 2              0                   0                  0               1  ...
# 4              0                   0                  0               0  ...
# 6              0                   0                  0               0  ...
# 7              0                   0                  0               0  ...
#
#    MotoristKilled              ContributingFactor  \
# 0               0                     Unspecified
# 2               0   Failure to Yield Right-of-Way
# 4               0  Driver Inattention/Distraction
# 6               0  Driver Inattention/Distraction
# 7               0                     Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                           NaN
# 2                            NaN                           NaN
# 4                            NaN                           NaN
# 6                            NaN                           NaN
# 7                            NaN                           NaN
#
#   CONTRIBUTING FACTOR VEHICLE 5 CollisionID  \
# 0                           NaN     4308629
# 2                           NaN     4307292
# 4                           NaN     4305053
# 6                           NaN     4305083
# 7                           NaN     4307401
#
#                            VehicleType  VEHICLE TYPE CODE 3  \
# 0  Station Wagon/Sport Utility Vehicle                  NaN
# 2  Station Wagon/Sport Utility Vehicle                  NaN
# 4                                Sedan                  NaN
# 6                                Sedan                  NaN
# 7                                Sedan                  NaN
#
#   VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                 NaN                 NaN
# 2                 NaN                 NaN
# 4                 NaN                 NaN
# 6                 NaN                 NaN
# 7                 NaN                 NaN
#
# [5 rows x 22 columns]

# %%
crash_count = crashes2020_df.groupby(['Borough']).count()
crash_count
# Out:
#                CrashDate  CrashTime  Latitude  Longitude  ON STREET NAME  \
# Borough
# BRONX                563        563       563        563             308
# BROOKLYN             895        895       895        895             507
# MANHATTAN            255        255       255        255             167
# QUEENS               689        689       689        689             456
# STATEN ISLAND        116        116       116        116              70
#
#                CROSS STREET NAME  OFF STREET NAME  PersonsInjured  \
# Borough
# BRONX                        308              255             563
# BROOKLYN                     507              388             895
# MANHATTAN                    167               88             255
# QUEENS                       455              233             689
# STATEN ISLAND                 70               46             116
#
#                PersonsKilled  PedestriansInjured  ...  MotoristKilled  \
# Borough                                           ...
# BRONX                    563                 563  ...             563
# BROOKLYN                 895                 895  ...             895
# MANHATTAN                255                 255  ...             255
# QUEENS                   689                 689  ...             689
# STATEN ISLAND            116                 116  ...             116
#
#                ContributingFactor  CONTRIBUTING FACTOR VEHICLE 3  \
# Borough
# BRONX                         561                             56
# BROOKLYN                      891                            116
# MANHATTAN                     254                             17
# QUEENS                        688                             79
# STATEN ISLAND                 116                             11
#
#                CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# Borough
# BRONX                                     16                              8
# BROOKLYN                                  39                             13
# MANHATTAN                                  5                              1
# QUEENS                                    21                              7
# STATEN ISLAND                              3                              1
#
#                CollisionID  VehicleType  VEHICLE TYPE CODE 3  \
# Borough
# BRONX                  563          554                   53
# BROOKLYN               895          883                  114
# MANHATTAN              255          255                   16
# QUEENS                 689          685                   71
# STATEN ISLAND          116          115                   10
#
#                VEHICLE TYPE CODE 4  VEHICLE TYPE CODE 5
# Borough
# BRONX                           15                    8
# BROOKLYN                        38                   13
# MANHATTAN                        5                    1
# QUEENS                          21                    6
# STATEN ISLAND                    3                    1
#
# [5 rows x 24 columns]

# %%
crash_count = crash_count.rename(columns={"CrashDate": "CrashCount"})

# %%
#del crash_count['CrashTime']
#del crash_count['Latitude']
#del crash_count['Longitude']
#del crash_count['PersonsInjured']
#del crash_count['PersonsKilled']
#del crash_count['PedestriansInjured']
#del crash_count['PedestriansKilled']
#del crash_count['CyclistInjured']
#del crash_count['CyclistKilled']
#del crash_count['MotoristInjured']
#del crash_count['MotoristKilled']
#del crash_count['ContributingFactor']
#del crash_count['VehicleType']
#del crash_count['CollisionID']

# %%
crash_count
# Out:
#                CrashCount  ON STREET NAME  CROSS STREET NAME  OFF STREET NAME  \
# Borough
# BRONX                 563             308                308              255
# BROOKLYN              895             507                507              388
# MANHATTAN             255             167                167               88
# QUEENS                689             456                455              233
# STATEN ISLAND         116              70                 70               46
#
#                CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# Borough
# BRONX                                     56                             16
# BROOKLYN                                 116                             39
# MANHATTAN                                 17                              5
# QUEENS                                    79                             21
# STATEN ISLAND                             11                              3
#
#                CONTRIBUTING FACTOR VEHICLE 5  VEHICLE TYPE CODE 3  \
# Borough
# BRONX                                      8                   53
# BROOKLYN                                  13                  114
# MANHATTAN                                  1                   16
# QUEENS                                     7                   71
# STATEN ISLAND                              1                   10
#
#                VEHICLE TYPE CODE 4  VEHICLE TYPE CODE 5
# Borough
# BRONX                           15                    8
# BROOKLYN                        38                   13
# MANHATTAN                        5                    1
# QUEENS                          21                    6
# STATEN ISLAND                    3                    1

# %%
crashcount = crash_count.reset_index()
crashcount
# Out:
#          Borough  CrashCount  ON STREET NAME  CROSS STREET NAME  \
# 0          BRONX         563             308                308
# 1       BROOKLYN         895             507                507
# 2      MANHATTAN         255             167                167
# 3         QUEENS         689             456                455
# 4  STATEN ISLAND         116              70                 70
#
#    OFF STREET NAME  CONTRIBUTING FACTOR VEHICLE 3  \
# 0              255                             56
# 1              388                            116
# 2               88                             17
# 3              233                             79
# 4               46                             11
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 0                             16                              8
# 1                             39                             13
# 2                              5                              1
# 3                             21                              7
# 4                              3                              1
#
#    VEHICLE TYPE CODE 3  VEHICLE TYPE CODE 4  VEHICLE TYPE CODE 5
# 0                   53                   15                    8
# 1                  114                   38                   13
# 2                   16                    5                    1
# 3                   71                   21                    6
# 4                   10                    3                    1

# %%
crashcount.to_csv("../Data/CrashCount.csv", index=False, header=True)

# %%
crashcount.to_json("../Data/totals.json", orient = 'records')

# %%
crashimpact.to_csv("../Data/CrashImpacts.csv", index=False, header=True)

# %% [markdown]
# # Borough Total Counts

# %%
crashes2020_df

# %%
total_df = crashes2020_df.groupby(['Borough']).sum()

# %%
total_df

# %%
del total_df["Latitude"]
del total_df["Longitude"]
del total_df["CollisionID"]

# %%
total_df

# %%
total_df.to_csv("../Data/TotalTable.csv", index=False, header=True)

# %%
crashimpact.to_csv("../Data/CrashImpacts.csv", index=False, header=True)

# %% [markdown]
# # April Totals

# %%
april_crashes_df = crashes2020_df

# %%
del april_crashes_df["CrashTime"]
del april_crashes_df["PersonsInjured"]
del april_crashes_df["PersonsKilled"]
del april_crashes_df["PedestriansInjured"]
del april_crashes_df["PedestriansKilled"]
del april_crashes_df["CyclistInjured"]
del april_crashes_df["CyclistKilled"]
del april_crashes_df["MotoristInjured"]
del april_crashes_df["MotoristKilled"]

# %%
april_crashes_df.head()

# %%
april_crashes_df.to_csv("../Data/AprilSummary.csv", index=False, header=True)

# %%
april_crashes_df

# %% [markdown]
# #
